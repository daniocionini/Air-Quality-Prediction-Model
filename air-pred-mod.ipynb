# %%
import pandas as pd

# %%
df = pd.read_csv('./air_quality.csv', sep=';')
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.shape
# Out:
# (9471, 17)

# %%
# identify where the missing values are in the dataset
df.isna().any()
# Out:
# Date             True
# Time             True
# CO(GT)           True
# PT08.S1(CO)      True
# NMHC(GT)         True
# C6H6(GT)         True
# PT08.S2(NMHC)    True
# NOx(GT)          True
# PT08.S3(NOx)     True
# NO2(GT)          True
# PT08.S4(NO2)     True
# PT08.S5(O3)      True
# T                True
# RH               True
# AH               True
# Unnamed: 15      True
# Unnamed: 16      True
# dtype: bool

# %%
# find % of missing values per single attribute in the dataset
nan = df.isna().sum()
tot = df.count()
perc = (nan*100)/tot
perc
# Out:
# Date             1.218339
# Time             1.218339
# CO(GT)           1.218339
# PT08.S1(CO)      1.218339
# NMHC(GT)         1.218339
# C6H6(GT)         1.218339
# PT08.S2(NMHC)    1.218339
# NOx(GT)          1.218339
# PT08.S3(NOx)     1.218339
# NO2(GT)          1.218339
# PT08.S4(NO2)     1.218339
# PT08.S5(O3)      1.218339
# T                1.218339
# RH               1.218339
# AH               1.218339
# Unnamed: 15           inf
# Unnamed: 16           inf
# dtype: float64

# %%
data = df.dropna(subset=['Date'])
data
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
data = data.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1)
data.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %%
data.shape
# Out:
# (9357, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
# dtypes: float64(8), object(7)
# memory usage: 1.1+ MB

# %%
data['CO(GT)'] = (data['CO(GT)'].replace(',','.',regex=True).astype(float))
data['C6H6(GT)'] = (data['C6H6(GT)'].replace(',','.',regex=True).astype(float))
data['T'] = (data['T'].replace(',','.',regex=True).astype(float))
data['RH'] = (data['RH'].replace(',','.',regex=True).astype(float))
data['AH'] = (data['AH'].replace(',','.',regex=True).astype(float))
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
data = data.loc[data["CO(GT)"] > -10] #remove all rows where CO is registered as -200 (missing value)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7674 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           7674 non-null   datetime64[ns]
#  1   Time           7674 non-null   object
#  2   CO(GT)         7674 non-null   float64
#  3   PT08.S1(CO)    7674 non-null   float64
#  4   NMHC(GT)       7674 non-null   float64
#  5   C6H6(GT)       7674 non-null   float64
#  6   PT08.S2(NMHC)  7674 non-null   float64
#  7   NOx(GT)        7674 non-null   float64
#  8   PT08.S3(NOx)   7674 non-null   float64
#  9   NO2(GT)        7674 non-null   float64
#  10  PT08.S4(NO2)   7674 non-null   float64
#  11  PT08.S5(O3)    7674 non-null   float64
#  12  T              7674 non-null   float64
#  13  RH             7674 non-null   float64
#  14  AH             7674 non-null   float64
# dtypes: datetime64[ns](1), float64(13), object(1)
# memory usage: 959.2+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0 2004-03-10  18.00.00     2.6       1360.0     150.0      11.9
# 1 2004-03-10  19.00.00     2.0       1292.0     112.0       9.4
# 2 2004-03-10  20.00.00     2.2       1402.0      88.0       9.0
# 3 2004-03-10  21.00.00     2.2       1376.0      80.0       9.2
# 4 2004-03-10  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
f = data.describe()
f
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  7674.000000  7674.000000  7674.000000  7674.000000    7674.000000
# mean      2.152750  1054.222700  -150.867735     1.233385     897.865911
# std       1.453252   341.261735   152.553382    43.276414     348.728250
# min       0.100000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       1.100000   927.000000  -200.000000     4.100000     716.000000
# 50%       1.800000  1062.000000  -200.000000     8.100000     903.000000
# 75%       2.900000  1235.000000  -200.000000    14.000000    1116.750000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  7674.000000   7674.000000  7674.000000   7674.000000  7674.000000
# mean    230.809747    782.760099    97.746286   1374.024498   990.038963
# std     233.316418    326.251230    85.341664    478.335306   470.166864
# ...

# %%
import matplotlib.pyplot as plt 
from scipy.stats import norm
import numpy as np
import seaborn as sns

# %%
s = f.drop(['count','min'])
s.plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot: >

# %%
x = np.arange(-10, 10, 0.01)
mean = f['CO(GT)'].iloc[[1]]
std = f['CO(GT)'].iloc[[2]]
median = f['CO(GT)'].iloc[[5]]

# %%
plt.figure(figsize=(10,8))
plt.plot(x, norm.pdf(x, mean, std))
plt.axvline(float(mean), 0, 0.95, label='Mean', c='red')
plt.axvline(float(median), 0, 0.93, label='Median', c='green')
plt.legend()
plt.show()

# %% [markdown]
# The mean > median meaning the distribution of **CO** is positively skewed

# %%
ts = data[['Date', 'CO(GT)']]
ts
# Out:
#            Date  CO(GT)
# 0    2004-03-10     2.6
# 1    2004-03-10     2.0
# 2    2004-03-10     2.2
# 3    2004-03-10     2.2
# 4    2004-03-10     1.6
# ...         ...     ...
# 9352 2005-04-04     3.1
# 9353 2005-04-04     2.4
# 9354 2005-04-04     2.4
# 9355 2005-04-04     2.1
# 9356 2005-04-04     2.2
#
# [7674 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
plt.plot_date(ts['Date'],ts['CO(GT)'])
plt.xticks(rotation=30, ha='right')
# Out:
# (array([12478., 12539., 12600., 12662., 12723., 12784., 12843.]),
#  [Text(12478.0, 0, '2004-03'),
#   Text(12539.0, 0, '2004-05'),
#   Text(12600.0, 0, '2004-07'),
#   Text(12662.0, 0, '2004-09'),
#   Text(12723.0, 0, '2004-11'),
#   Text(12784.0, 0, '2005-01'),
#   Text(12843.0, 0, '2005-03')])

# %%
sns.pairplot(data)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(data.corr(), cmap='BrBG', annot=True, linewidth=.5)
# Out:
# C:\Users\Premiere2022-PC1\AppData\Local\Temp\ipykernel_4972\746436299.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap='BrBG', annot=True, linewidth=.5)
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr()[['CO(GT)']].sort_values(
    by='CO(GT)', ascending=False),annot=True,cmap='BrBG')
# Out:
# C:\Users\Premiere2022-PC1\AppData\Local\Temp\ipykernel_4972\3881194407.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr()[['CO(GT)']].sort_values(
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(x='CO(GT)', y='NOx(GT)', data=data, palette='Dark2', s=80)
# Out:
# C:\Users\Premiere2022-PC1\AppData\Local\Temp\ipykernel_4972\2121118030.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='CO(GT)', y='NOx(GT)', data=data, palette='Dark2', s=80)
# <AxesSubplot: xlabel='CO(GT)', ylabel='NOx(GT)'>

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(x='CO(GT)', y='PT08.S5(O3)', data=data, palette='Dark2', s=80)
# Out:
# C:\Users\Premiere2022-PC1\AppData\Local\Temp\ipykernel_4972\217121529.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='CO(GT)', y='PT08.S5(O3)', data=data, palette='Dark2', s=80)
# <AxesSubplot: xlabel='CO(GT)', ylabel='PT08.S5(O3)'>
